# %% [markdown]
# # Mutual Fund  Analysis
# - Description:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('C:/Users/HP/OneDrive/Desktop/jupyter projects/Mutual_Fund_Project/Mutual_Funds.csv')
df
# Out:
#       Unnamed: 0                                             Scheme  \
# 0              0                  Kotak Corporate Bond Fund(M-IDCW)
# 1              1                       Kotak Corporate Bond Fund(G)
# 2              2               Aditya Birla SL Liquid Fund(DD-IDCW)
# 3              3                     Aditya Birla SL Liquid Fund(G)
# 4              4                Aditya Birla SL Liquid Fund(W-IDCW)
# ...          ...                                                ...
# 2551        2551  DSP Nifty SDL Plus G-Sec Sep 2027 50:50 Index ...
# 2552        2552  DSP Nifty SDL Plus G-Sec Sep 2027 50:50 Index ...
# 2553        2553  Aditya Birla SL CRISIL IBX AAA Mar 2024 Index ...
# 2554        2554  Aditya Birla SL CRISIL IBX AAA Mar 2024 Index ...
# 2555        2555  UTI Nifty SDL Plus AAA PSU Bond Apr 2026 75:25...
#
#                          Category         Type  \
# 0      Debt - Corporate Bond Fund   Open ended
# 1      Debt - Corporate Bond Fund   Open ended
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            2556 non-null   int64
#  1   Scheme                2556 non-null   object
#  2   Category              2556 non-null   object
#  3   Type                  2556 non-null   object
#  4   Benchmark             2556 non-null   object
#  5   Net_Asset_Value(Rs.)  2556 non-null   object
#  6   CAGR% 6 Months        2556 non-null   object
#  7   CAGR% 1 Year          2556 non-null   object
#  8   CAGR% 3 Year          2556 non-null   object
#  9   Min. Invest(Rs.)      2556 non-null   object
#  10  Exp. Ratio(%)         2518 non-null   object
#  11  SIP Min. Inv.(Rs.)    2462 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 239.8+ KB
#         Unnamed: 0
# count  2556.000000
# mean   1277.500000
# std     737.997967
# min       0.000000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                Scheme  \
# 0           0     Kotak Corporate Bond Fund(M-IDCW)
# 1           1          Kotak Corporate Bond Fund(G)
# 2           2  Aditya Birla SL Liquid Fund(DD-IDCW)
# 3           3        Aditya Birla SL Liquid Fund(G)
# 4           4   Aditya Birla SL Liquid Fund(W-IDCW)
#
#                       Category         Type                     Benchmark  \
# 0   Debt - Corporate Bond Fund   Open ended   CRISIL Corporate Bond Index
# 1   Debt - Corporate Bond Fund   Open ended   CRISIL Corporate Bond Index
# 2           Debt - Liquid Fund   Open ended                           N/A
# 3           Debt - Liquid Fund   Open ended                           N/A
# 4           Debt - Liquid Fund   Open ended                           N/A
#
#   Net_Asset_Value(Rs.) CAGR% 6 Months CAGR% 1 Year CAGR% 3 Year  \
# 0             1,035.21           5.05         3.69         5.29
# 1             3,133.58           5.05         3.69         5.32
# ...

# %% [markdown]
# # PERFORMING DATA CLEANING:
# - Checking for NULL Value and Dataset info.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Scheme                   0
# Category                 0
# Type                     0
# Benchmark                0
# Net_Asset_Value(Rs.)     0
# CAGR% 6 Months           0
# CAGR% 1 Year             0
# CAGR% 3 Year             0
# Min. Invest(Rs.)         0
# Exp. Ratio(%)           38
# SIP Min. Inv.(Rs.)      94
# dtype: int64

# %% [markdown]
# - Checking if the Missing data is less than the Total Data in that particular Coloumn:

# %%
Total_null_values=df.isnull().sum()
Total_values=df.isnull().count()
print(Total_null_values/Total_values)
# Out:
# Unnamed: 0              0.000000
# Scheme                  0.000000
# Category                0.000000
# Type                    0.000000
# Benchmark               0.000000
# Net_Asset_Value(Rs.)    0.000000
# CAGR% 6 Months          0.000000
# CAGR% 1 Year            0.000000
# CAGR% 3 Year            0.000000
# Min. Invest(Rs.)        0.000000
# Exp. Ratio(%)           0.014867
# SIP Min. Inv.(Rs.)      0.036776
# dtype: float64

# %% [markdown]
# - Observation: Some Null value were observed in Exp.Ratio(%) and SIP Min. Inv.(Rs.) and account to be less than 5% of the total Data.
# - Action: We can remove the Null Values from the dataset as they account to be less than 5%.

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Scheme                  0
# Category                0
# Type                    0
# Benchmark               0
# Net_Asset_Value(Rs.)    0
# CAGR% 6 Months          0
# CAGR% 1 Year            0
# CAGR% 3 Year            0
# Min. Invest(Rs.)        0
# Exp. Ratio(%)           0
# SIP Min. Inv.(Rs.)      0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                                       Scheme  \
# 0           0            Kotak Corporate Bond Fund(M-IDCW)
# 1           1                 Kotak Corporate Bond Fund(G)
# 3           3               Aditya Birla SL Liquid Fund(G)
# 5           5   Aditya Birla SL Money Manager Fund(W-IDCW)
# 6           6  Aditya Birla SL Money Manager Fund(DD-IDCW)
#
#                       Category         Type                     Benchmark  \
# 0   Debt - Corporate Bond Fund   Open ended   CRISIL Corporate Bond Index
# 1   Debt - Corporate Bond Fund   Open ended   CRISIL Corporate Bond Index
# 3           Debt - Liquid Fund   Open ended                           N/A
# 5     Debt - Money Market Fund   Open ended      Nifty Money Market Index
# 6     Debt - Money Market Fund   Open ended      Nifty Money Market Index
#
#   Net_Asset_Value(Rs.) CAGR% 6 Months CAGR% 1 Year CAGR% 3 Year  \
# 0             1,035.21           5.05         3.69         5.29
# ...

# %% [markdown]
# - Removal of string after (-) or Removal of Subcategory in Category column.

# %%
def handlecategory(value):
    value=str(value).split('-')
    value=value[0]
    return (value)
df['Category']=df['Category'].apply(handlecategory)
df.head()
# Out:
#    Unnamed: 0                                       Scheme Category  \
# 0           0            Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1           1                 Kotak Corporate Bond Fund(G)    Debt
# 3           3               Aditya Birla SL Liquid Fund(G)    Debt
# 5           5   Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6           6  Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
#
#           Type                     Benchmark Net_Asset_Value(Rs.)  \
# 0   Open ended   CRISIL Corporate Bond Index             1,035.21
# 1   Open ended   CRISIL Corporate Bond Index             3,133.58
# 3   Open ended                           N/A               356.66
# 5   Open ended      Nifty Money Market Index               100.18
# 6   Open ended      Nifty Money Market Index               100.02
#
#   CAGR% 6 Months CAGR% 1 Year CAGR% 3 Year Min. Invest(Rs.) Exp. Ratio(%)  \
# 0           5.05         3.69         5.29         5,000.00          0.67
# ...

# %%
df
# Out:
#       Unnamed: 0                                             Scheme Category  \
# 0              0                  Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1              1                       Kotak Corporate Bond Fund(G)    Debt
# 3              3                     Aditya Birla SL Liquid Fund(G)    Debt
# 5              5         Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6              6        Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
# ...          ...                                                ...      ...
# 2544        2544     Tata Nifty G-Sec Dec 2026 Index Fund-Reg(IDCW)    Debt
# 2545        2545                 TRUSTMF Corporate Bond Fund-Reg(G)    Debt
# 2546        2546            TRUSTMF Corporate Bond Fund-Reg(M-IDCW)    Debt
# 2547        2547  DSP CRISIL SDL Plus G-Sec Apr 2033 50:50 Index...    Debt
# 2548        2548  DSP CRISIL SDL Plus G-Sec Apr 2033 50:50 Index...    Debt
#
# ...

# %% [markdown]
# - Removing Scheme column from the dataset.

# %%
# df=df.drop(columns=["Scheme"])
df.head()
# Out:
#    Unnamed: 0                                       Scheme Category  \
# 0           0            Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1           1                 Kotak Corporate Bond Fund(G)    Debt
# 3           3               Aditya Birla SL Liquid Fund(G)    Debt
# 5           5   Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6           6  Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
#
#           Type                     Benchmark Net_Asset_Value(Rs.)  \
# 0   Open ended   CRISIL Corporate Bond Index             1,035.21
# 1   Open ended   CRISIL Corporate Bond Index             3,133.58
# 3   Open ended                           N/A               356.66
# 5   Open ended      Nifty Money Market Index               100.18
# 6   Open ended      Nifty Money Market Index               100.02
#
#   CAGR% 6 Months CAGR% 1 Year CAGR% 3 Year Min. Invest(Rs.) Exp. Ratio(%)  \
# 0           5.05         3.69         5.29         5,000.00          0.67
# ...

# %% [markdown]
# # Analysing the dataset
# # 1. Concentration of  differnt types Mutual Funds present in the Indian Market.

# %%
Total_Category_Distribution=df.groupby("Category")["Net_Asset_Value(Rs.)"].count()
print(Total_Category_Distribution)
Total_Categories=df["Category"].count()
Total_Categories
Distribution_of_MutualFunds=((Total_Category_Distribution*100)/Total_Categories).sort_values( ascending=False)
print()
print("Mutual Fund %")
print(Distribution_of_MutualFunds)

plt.figure(figsize=(15, 5))
plt.bar(Distribution_of_MutualFunds.index, Distribution_of_MutualFunds.values,alpha=0.8,color="navy")
plt.xticks(rotation=45)

plt.plot(Distribution_of_MutualFunds,color='red')
plt.xlabel("Types of Mutual Funds",size=20)
plt.ylabel("%  in IndianMarket ",size=20)
# Out:
# Category
# Debt                            999
# ETFs                              3
# Equity                          741
# FoFs (Domestic / Overseas )      22
# FoFs (Domestic)                 109
# FoFs (Overseas)                  51
# Hybrid                          323
# Index Funds                     137
# Solution Oriented                57
# Name: Net_Asset_Value(Rs.), dtype: int64
#
# Mutual Fund %
# Category
# Debt                            40.909091
# Equity                          30.343980
# Hybrid                          13.226863
# Index Funds                      5.610156
# FoFs (Domestic)                  4.463554
# Solution Oriented                2.334152
# FoFs (Overseas)                  2.088452
# FoFs (Domestic / Overseas )      0.900901
# ETFs                             0.122850
# Name: Net_Asset_Value(Rs.), dtype: float64
# Text(0, 0.5, '%  in IndianMarket ')

# %% [markdown]
# # Conclusion:
# - About 40% of the available mutual funds in the market are Debt mutual funds followed by Equity(30%) and Hybrid(13%) Funds.
# 1. Debt = 40%
# 2. Equity = 30%
# 3. Hybrid= 13%
# 4. Others= 17%

# %% [markdown]
# # 2. Average Minimum Sip amount required to Start in differnt types of funds.

# %%
df.head()
df
# Out:
#       Unnamed: 0                                             Scheme Category  \
# 0              0                  Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1              1                       Kotak Corporate Bond Fund(G)    Debt
# 3              3                     Aditya Birla SL Liquid Fund(G)    Debt
# 5              5         Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6              6        Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
# ...          ...                                                ...      ...
# 2544        2544     Tata Nifty G-Sec Dec 2026 Index Fund-Reg(IDCW)    Debt
# 2545        2545                 TRUSTMF Corporate Bond Fund-Reg(G)    Debt
# 2546        2546            TRUSTMF Corporate Bond Fund-Reg(M-IDCW)    Debt
# 2547        2547  DSP CRISIL SDL Plus G-Sec Apr 2033 50:50 Index...    Debt
# 2548        2548  DSP CRISIL SDL Plus G-Sec Apr 2033 50:50 Index...    Debt
#
# ...

# %%
Categorical_features=[col for col in df.columns if df[col].dtype=='O']
print(Categorical_features)
# ans=df["SIP Min. Inv.(Rs.)"].sum()
    
df1=df.copy()

df1["SIP Min. Inv.(Rs.)"]=df1["SIP Min. Inv.(Rs.)"].apply(handlevalue)
#importabt to convert categorical varible to numerical

df1["SIP Min. Inv.(Rs.)"] = df1["SIP Min. Inv.(Rs.)"].apply(lambda x: int(float(x.replace(',', ''))))


df1["SIP Min. Inv.(Rs.)"]


Minsip_amount=df1.groupby("Category")["SIP Min. Inv.(Rs.)"].mean().sort_values( ascending=True)

Minsip_amount
plt.figure(figsize=(15, 5))
plt.bar(Minsip_amount.index,Minsip_amount.values,alpha=0.8,color="green")
plt.xticks(rotation=45)


plt.xlabel("Types of Mutual Funds",size=20)
plt.ylabel("Average MIN SIP  ",size=20)
# Out:
# ['Scheme', 'Category', 'Type', 'Benchmark', 'Net_Asset_Value(Rs.)', 'CAGR% 6 Months', 'CAGR% 1 Year', 'CAGR% 3 Year', 'Min. Invest(Rs.)', 'Exp. Ratio(%)', 'SIP Min. Inv.(Rs.)']
# Text(0, 0.5, 'Average MIN SIP  ')

# %% [markdown]
# # Conclusion:
# - ETFs,Equity and Hybrid require minimum amount of Monthy sips.
# - Index Funds,Debt require the maximum amount of monthly sips.

# %% [markdown]
# # Conversion of categorical column to numerical data  for these fields:
# 1. Net_Asset_Value(Rs.)
# 2. CAGR% 6 Months
# 3. CAGR% 1 Year
# 4. CAGR% 3 Year
# 5. 	Min. Invest(Rs.)
# 6. 	Exp. Ratio(%)

# %%
def handlevalue(value):
    value=str(value).split('.')
    value=value[0]
    return (value)
# For ["Net_Asset_Value(Rs.)"]

df1["Net_Asset_Value(Rs.)"]=df1["Net_Asset_Value(Rs.)"].apply(handlevalue)
df1["Net_Asset_Value(Rs.)"] = df1["Net_Asset_Value(Rs.)"].apply(lambda x: int(float(x.replace(',', ''))))
df1["Net_Asset_Value(Rs.)"]

# For CAGR% 6 Months
rows_to_drop = df1[df1['CAGR% 6 Months'] == '-'].index
df1=df1.drop(rows_to_drop)


df1["CAGR% 6 Months"] = df1["CAGR% 6 Months"].apply(lambda x: int(float(x.replace('.', ''))))
df1["CAGR% 6 Months"]
df1["CAGR% 6 Months"]=(df1["CAGR% 6 Months"]/100)
df1["CAGR% 6 Months"]

#For CAGR% 1 Year
rows_to_drop = df1[df1['CAGR% 1 Year'] == '-'].index
df1=df1.drop(rows_to_drop)
df1["CAGR% 1 Year"] = df1["CAGR% 1 Year"].apply(lambda x: int(float(x.replace('.', ''))))
df1["CAGR% 1 Year"]
df1["CAGR% 1 Year"]=(df1["CAGR% 1 Year"]/100)
df1["CAGR% 1 Year"]

# For 'CAGR% 3 Year'
rows_to_drop = df1[df1['CAGR% 3 Year'] == '-'].index
df1=df1.drop(rows_to_drop)
df1['CAGR% 3 Year'] = df1['CAGR% 3 Year'].apply(lambda x: int(float(x.replace('.', ''))))
df1['CAGR% 3 Year']
df1['CAGR% 3 Year']=(df1['CAGR% 3 Year']/100)
df1['CAGR% 3 Year']

#For Min. Invest(Rs.)

df1["Min. Invest(Rs.)"]=df1["Min. Invest(Rs.)"].apply(handlevalue)


df1["Min. Invest(Rs.)"] = df1["Min. Invest(Rs.)"].apply(lambda x: int(float(x.replace(',', ''))))
df1['Min. Invest(Rs.)']

#For Exp. Ratio(%)
df1["Exp. Ratio(%)"] = df1["Exp. Ratio(%)"].apply(lambda x: int(float(x.replace('.', ''))))
df1["Exp. Ratio(%)"]=df1["Exp. Ratio(%)"]/100
df1["Exp. Ratio(%)"]
# Out:
# 0       0.67
# 1       0.67
# 3       0.34
# 5       0.33
# 6       0.33
#         ...
# 1957    0.04
# 1958    0.04
# 1990    0.48
# 1991    0.48
# 1992    0.48
# Name: Exp. Ratio(%), Length: 1573, dtype: float64

# %% [markdown]
# # 3. Wealth concentration in different type of Funds:

# %%
df1.head()
# Out:
#    Unnamed: 0                                       Scheme Category  \
# 0           0            Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1           1                 Kotak Corporate Bond Fund(G)    Debt
# 3           3               Aditya Birla SL Liquid Fund(G)    Debt
# 5           5   Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6           6  Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
#
#           Type                     Benchmark  Net_Asset_Value(Rs.)  \
# 0   Open ended   CRISIL Corporate Bond Index                  1035
# 1   Open ended   CRISIL Corporate Bond Index                  3133
# 3   Open ended                           N/A                   356
# 5   Open ended      Nifty Money Market Index                   100
# 6   Open ended      Nifty Money Market Index                   100
#
#    CAGR% 6 Months  CAGR% 1 Year  CAGR% 3 Year  Min. Invest(Rs.)  \
# 0            5.05          3.69          5.29              5000
# ...

# %%
WealtDistribution_In_MutualFunds=df1.groupby("Category")["Net_Asset_Value(Rs.)"].sum()
print(WealtDistribution_In_MutualFunds)
Total_wealth=df1["Net_Asset_Value(Rs.)"].sum()
Concentration_of_wealth=((WealtDistribution_In_MutualFunds*100)/Total_wealth).sort_values(ascending=False)
print(Concentration_of_wealth)

plt.bar(Concentration_of_wealth.index,Concentration_of_wealth.values,color="navy")
plt.xticks(rotation=60)
plt.plot(Concentration_of_wealth,color="red")


plt.xlabel("Types of Mutual Funds",size=10)
plt.ylabel("%  of Total Wealth ",size=10)
# Out:
# Category
# Debt                            355498
# Equity                           48801
# FoFs (Domestic / Overseas )        338
# FoFs (Domestic)                   1939
# FoFs (Overseas)                    553
# Hybrid                            9532
# Index Funds                       2681
# Solution Oriented                 1144
# Name: Net_Asset_Value(Rs.), dtype: int64
# Category
# Debt                            84.544551
# Equity                          11.605856
# Hybrid                           2.266901
# Index Funds                      0.637596
# FoFs (Domestic)                  0.461133
# Solution Oriented                0.272066
# FoFs (Overseas)                  0.131514
# FoFs (Domestic / Overseas )      0.080383
# Name: Net_Asset_Value(Rs.), dtype: float64
# Text(0, 0.5, '%  of Total Wealth ')

# %% [markdown]
# # Conclusion:
# - 84 % of wealth is concentrated in Debt mutual funds .
# - 11 % of wealth is concentrated in Equity based mutual funds.

# %% [markdown]
# # 4. Top 10 mutual funds in india according to Net asset value

# %%
df1.head(10)
df2=(df1.groupby("Scheme")["Net_Asset_Value(Rs.)"].sum()).sort_values(ascending=False)
df2_top10=df2.head(10)
df2_top10
# Out:
# Scheme
# Nippon India Liquid Fund(G)                    5407
# SBI Magnum Ultra Short Duration Fund-Reg(G)    5051
# HDFC Money Market Fund(G)                      4798
# HDFC Liquid Fund(G)                            4347
# LIC MF Liquid Fund-Reg(G)                      4005
# Tata Money Market Fund-Reg(G)                  3958
# UTI Ultra Short Term Fund-Reg(G)               3602
# SBI Overnight Fund-Reg(G)                      3581
# Tata Liquid Fund-Reg(G)                        3489
# Nippon India Money Market Fund(G)              3479
# Name: Net_Asset_Value(Rs.), dtype: int64

# %%
plt.figure(figsize=(25, 10))

plt.bar(df2_top10.index, df2_top10.values,color="green")

plt.xlabel('Scheme')
plt.xticks(rotation=45,size=15)
plt.yticks(rotation=0,size=15)
plt.ylabel('Net_Asset_Value(CR.)',size=20,color="navy")
plt.title('Top 10 Mutual Funds Net asset Value',size=20,color="navy")
plt.show()

# %% [markdown]
# # Conclusion: Rankings according to Net asset value
# 1. Nippon India Liquid Fund(G)                   - 5407 cr
# 2. SBI Magnum Ultra Short Duration Fund-Reg(G)   - 5051 cr
# 3. HDFC Money Market Fund(G)                     - 4798 cr
# 4. HDFC Liquid Fund(G)                           - 4347 cr
# 5. LIC MF Liquid Fund-Reg(G)                     - 4005 cr
# 6. Tata Money Market Fund-Reg(G)                 - 3958 cr
# 7. UTI Ultra Short Term Fund-Reg(G)              - 3602 cr
# 8. SBI Overnight Fund-Reg(G)                     - 3581 cr
# 9. Tata Liquid Fund-Reg(G)                       - 3489 cr
# 10. Nippon India Money Market Fund(G)             - 3479 cr

# %% [markdown]
# # 5.Analysing performace of differnt funds over different time periods:

# %%
df1
# Out:
#       Unnamed: 0                                       Scheme Category  \
# 0              0            Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1              1                 Kotak Corporate Bond Fund(G)    Debt
# 3              3               Aditya Birla SL Liquid Fund(G)    Debt
# 5              5   Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6              6  Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
# ...          ...                                          ...      ...
# 1957        1957     LIC MF Ultra Short Term Fund-Reg(W-IDCW)    Debt
# 1958        1958     LIC MF Ultra Short Term Fund-Reg(M-IDCW)    Debt
# 1990        1990  HSBC Ultra Short Duration Fund-Reg(DD-IDCW)    Debt
# 1991        1991   HSBC Ultra Short Duration Fund-Reg(W-IDCW)    Debt
# 1992        1992   HSBC Ultra Short Duration Fund-Reg(M-IDCW)    Debt
#
#              Type                               Benchmark  \
# 0      Open ended             CRISIL Corporate Bond Index
# ...

# %%
SixmonthsCagr=df1.groupby("Category")["CAGR% 6 Months"].mean()
plt.figure(figsize=(15,10))
plt.plot(SixmonthsCagr.index,SixmonthsCagr.values,color="green")

plt.xticks(rotation=45,size=15)
plt.yticks(rotation=0,size=15)
OneyrCagr=df1.groupby("Category")["CAGR% 1 Year"].mean()
plt.plot(OneyrCagr.index,OneyrCagr.values,color="red")

ThreeyrCagr=df1.groupby("Category")["CAGR% 3 Year"].mean()
plt.plot(ThreeyrCagr.index,ThreeyrCagr.values,color="black")
plt.legend
plt.show()

# %% [markdown]
# - Green--->6 MONTHS CAGR
# - RED--->1 YR CAGR
# - BLACK--->3 YR CAGR

# %% [markdown]
# # Conclusion
# - Debt and Hybrid  mutual fund give out the least returns .
# - Equities,FOFs(Domestic/Overseas) and Index Funds give the maximum return in 1Yr and 3Yr time frames.

# %% [markdown]
# # 6. Expense ratios across different Funds

# %%
df1.head()
# Out:
#    Unnamed: 0                                       Scheme Category  \
# 0           0            Kotak Corporate Bond Fund(M-IDCW)    Debt
# 1           1                 Kotak Corporate Bond Fund(G)    Debt
# 3           3               Aditya Birla SL Liquid Fund(G)    Debt
# 5           5   Aditya Birla SL Money Manager Fund(W-IDCW)    Debt
# 6           6  Aditya Birla SL Money Manager Fund(DD-IDCW)    Debt
#
#           Type                     Benchmark  Net_Asset_Value(Rs.)  \
# 0   Open ended   CRISIL Corporate Bond Index                  1035
# 1   Open ended   CRISIL Corporate Bond Index                  3133
# 3   Open ended                           N/A                   356
# 5   Open ended      Nifty Money Market Index                   100
# 6   Open ended      Nifty Money Market Index                   100
#
#    CAGR% 6 Months  CAGR% 1 Year  CAGR% 3 Year  Min. Invest(Rs.)  \
# 0            5.05          3.69          5.29              5000
# ...

# %%
Expense_ratios=(df1.groupby("Category")["Exp. Ratio(%)"].mean())
plt.figure(figsize=(15,10))
plt.bar(Expense_ratios.index,Expense_ratios.values,color="green")
plt.title("Expense Ratios ",size=40)
plt.xlabel("Types of Funds",size=25)
plt.ylabel("Expense Ratios %",size=25)
plt.xticks(rotation=45,size=15)
plt.yticks(rotation=0,size=15)

# plt.plot(OneyrCagr.index,OneyrCagr.values,color="red")
# Out:
# (array([0. , 0.5, 1. , 1.5, 2. , 2.5]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.5, '0.5'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.5, '1.5'),
#   Text(0, 2.0, '2.0'),
#   Text(0, 2.5, '2.5')])

# %%
Expense_ratios=(df1.groupby("Category")["Exp. Ratio(%)"].mean())
plt.figure(figsize=(15,9))
plt.bar(Expense_ratios.index,Expense_ratios.values,color="green")
plt.title("Expense Ratios vs 1 Yr avg Returns",size=30)
plt.xlabel("Types of Funds",size=25)
plt.ylabel("%",size=25)

plt.xticks(rotation=45,size=15)
plt.yticks(rotation=0,size=15)

plt.plot(OneyrCagr.index,OneyrCagr.values,color="red",label="Yearly Returns")

# %% [markdown]
# # Conlusion:
# - Solution Oriented and Equity charge highest expense ratios.

# %% [markdown]
# # Final Conclusions:
# - About 40% of the available mutual funds in the market are Debt mutual funds followed by Equity(30%) in the Indian Market
# - More than 80% indian investments are  in Debt mutual Funds,followed 11% in Equity
# - Most Indians prefer low Risk ,low return type Mutual Funds.
# - Equities,FOFs(Domestic/Overseas) and Index funds give out best returns on Longer time Frames
# - Debt and Hybrid mutual Funds have given out the least returns over Short Term and Long Term.
# - Solution Oriented Funds charge the highest expense ratios.
# - Equity based Funds charge the 2nd highest Expense ratio but give out similar or close returns to Index Funds which charge alot less Expense Ratio.

# %% [markdown]
# - Top 10 Mutual Funds according to Net Asset Value were:
# 1. Nippon India Liquid Fund(G)                   - 5407 cr
# 2. SBI Magnum Ultra Short Duration Fund-Reg(G)   - 5051 cr
# 3. HDFC Money Market Fund(G)                     - 4798 cr
# 4. HDFC Liquid Fund(G)                           - 4347 cr
# 5. LIC MF Liquid Fund-Reg(G)                     - 4005 cr
# 6. Tata Money Market Fund-Reg(G)                 - 3958 cr
# 7. UTI Ultra Short Term Fund-Reg(G)              - 3602 cr
# 8. SBI Overnight Fund-Reg(G)                     - 3581 cr
# 9. Tata Liquid Fund-Reg(G)                       - 3489 cr
# 10. Nippon India Money Market Fund(G)             - 3479 cr
